# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
# your code here
from scipy.stats import uniform

# Define the parameters for the uniform distribution
a = 10  # minimum value
b = 20  # maximum value

# Generate a sample from the distribution
sample_size = 3000
data_uniform = uniform.rvs(size=sample_size, loc=a, scale=b-a)

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def gen_uniform_ran_numbers(bottom, ceiling, count):
    data_uniform = uniform.rvs(size=count, loc=bottom, scale=ceiling - bottom)
    return data_uniform

# %%
# your code here
# Call the function with the specified parameters
gen1 = gen_uniform_ran_numbers(bottom=10, ceiling=15, count=100)
gen2 = gen_uniform_ran_numbers(bottom=10, ceiling=60, count=1000)

# %%
# your code here
# Plotting the histograms
plt.figure(figsize=(12, 6))

# Histogram for the first set of parameters
plt.subplot(1, 2, 1)
sns.histplot(gen1, bins=10, color='blue', kde=False)
sns.set_style('whitegrid')
plt.title('Uniform Distribution (10 to 15)')
plt.xlabel('Value')
plt.ylabel('Count')
plt.grid()

# Histogram for the second set of parameters
plt.subplot(1, 2, 2)
sns.histplot(gen2, bins=10, color='green', kde=False)
sns.set_style('whitegrid')
plt.title('Uniform Distribution (10 to 60)')
plt.xlabel('Value')
plt.ylabel('Count')
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
The key differences between the two distributions lie in their range, density, and overall appearance in the histogram. The first distribution is concentrated and narrow, while the second is broad and evenly distributed, highlighting the characteristics of uniform distributions based on their defined parameters.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# your code here
def gen_normal_ran_numbers(mu, sigma, count):
    data_normal = norm.rvs(size=count, loc=mu, scale=sigma)
    return data_normal

# %%
# your code here
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
gen1 = gen_normal_ran_numbers(mu=10, sigma=1, count=1000)

# %%
# your code here
# Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
gen2 = gen_normal_ran_numbers(mu=10, sigma=50, count=1000)

# %%
# your code here
# Plotting the distributions
plt.figure(figsize=(12, 6))

# Histogram for the first set of parameters
plt.subplot(1, 2, 1)
sns.histplot(gen1, bins=30, color='blue', kde=True)
sns.set_style('whitegrid')
plt.title('Normal Distribution (mean=10, std_dev=1)')
plt.xlabel('Value')
plt.ylabel('Count')
plt.grid()

# Histogram for the second set of parameters
plt.subplot(1, 2, 2)
sns.histplot(gen2, bins=30, color='green', kde=True)
sns.set_style('whitegrid')
plt.title('Normal Distribution (mean=10, std_dev=50)')
plt.xlabel('Value')
plt.ylabel('Count')
plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# Your answer here
#  The primary difference between the two distributions is the degree of variability represented by the standard deviation. A smaller standard deviation leads to a more concentrated distribution, while a larger standard deviation indicates a greater spread of values around the mean.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
# your code here
# Load the data
vehicles = pd.read_csv('vehicles.csv')

# Display the first few rows of the dataset
display(vehicles.head())
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
plt.figure(figsize=(10, 6))
sns.histplot(vehicles['Fuel Barrels/Year'], bins=30, kde=True, color='blue')
plt.title('Distribution of Fuel Barrels/Year')
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %%
# your code here

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
plt.figure(figsize=(10, 6))
sns.histplot(vehicles['CO2 Emission Grams/Mile'], bins=30, kde=True, color='green')
sns.set_style('whitegrid')
plt.title('Distribution of CO2 Emission Grams/Mile')
plt.xlabel('CO2 Emission Grams/Mile')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %%
# your code here

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
plt.figure(figsize=(10, 6))
sns.histplot(vehicles['Combined MPG'], bins=30, kde=True, color='orange')
sns.set_style('whitegrid')
plt.title('Distribution of Combined MPG')
plt.xlabel('Combined MPG')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %%
# your code here

# %%
# your code here

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your code here
Fuel Barrels/Year
Skewness: If this variable is positively skewed (long tail to the right), it indicates that most vehicles consume a lower amount of fuel barrels per year, with a few outliers consuming significantly more.

Kurtosis: A high kurtosis may suggest the presence of outliers or a sharper peak, which can also indicate non-normality.

# %%
# your code here
CO2 Emission Grams/Mile
Skewness: This variable may also exhibit positive skewness if most vehicles have lower CO2 emissions, while a few emit significantly higher amounts.

Kurtosis: If the kurtosis is too high or too low, it suggests a distribution that deviates from normality, often due to outliers.

# %%
# your code here
Skewness: If the distribution is skewed, it might mean that there are more vehicles with lower miles per gallon (MPG), and a few high MPG vehicles creating a long tail.

Kurtosis: Similar to the other variables, the presence of outliers or a sharp peak can influence kurtosis and indicate a non-normal distribution.

None of them are normally ditributed.

# %%
# your code here

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
def generate_exponential_numbers(mean, size):
    # Calculate the rate parameter (lambda)
    rate = 1 / mean
    # Generate exponentially distributed numbers
    numbers = np.random.exponential(1 / rate, size)
    return numbers

# Generate two sequences
sequence_10 = generate_exponential_numbers(mean=10, size=10)
sequence_100 = generate_exponential_numbers(mean=10, size=100)

# Set the style for the plots
sns.set_style('whitegrid')

# Create histograms
plt.figure(figsize=(12, 6))

# Histogram for the sequence of 10
plt.subplot(1, 2, 1)
sns.histplot(sequence_10, bins=100, kde=True, color='blue')
plt.title('Exponential Distribution (Size 10)')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Histogram for the sequence of 100
plt.subplot(1, 2, 2)
sns.histplot(sequence_100, bins=100, kde=True, color='orange')
plt.title('Exponential Distribution (Size 100)')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your code here
mu = 10  # mean time spent in minutes
lambda_param = 1 / mu  # rate parameter
x = 15  # time in minutes

# Calculate the probability P(X < x)
probability = 1 - np.exp(-lambda_param * x)

# Print the result
print(f"The probability that a customer will spend less than {x} minutes in the bank is: {probability:.4f}")
# Out:
# The probability that a customer will spend less than 15 minutes in the bank is: 0.7769

# %%
# your answer here
# Hint: This is same as saying P(x<15)
The result indicates that there is approximately a 77.69% probability that a customer will spend less than 15 minutes in the bank, given the exponential distribution with a mean of 10 minutes.

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your code here
mu = 10  # mean time spent in minutes
lambda_param = 1 / mu  # rate parameter
x = 15  # time in minutes

# Calculate the probability P(X > x)
probability_more_than_15 = np.exp(-lambda_param * x)

# Print the result
print(f"The probability that a customer will spend more than {x} minutes in the bank is: {probability_more_than_15:.4f}")
# Out:
# The probability that a customer will spend more than 15 minutes in the bank is: 0.2231
